# %%
from utils import *

# %%
# Out:
# driver_imgs_list.csv.zip        Project plan_Evans_Copy.ipynb
# imgs.zip                        Project plan.ipynb
# Project plan-a.liz-Copy1.ipynb  Project plan-Jared Copy.ipynb
# Project plan-a.liz.ipynb        Project plan-ray.ipynb
# Project plan-Copy1.ipynb        sample_submission.csv.zip
# Project plan-Copy2.ipynb        test/
# Project plan-Copy3.ipynb        train/
# Project plan-Copy4.ipynb        Untitled1.ipynb
# Project plan-Copy5.ipynb        Untitled.ipynb

# %%
TEST_PATH="test/"

# %%
TRAIN_PATH="train/"

# %%
from PIL import Image

# %%
im=Image.open(TRAIN_PATH+"c0/img_100145.jpg")

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7F002C256B10>

# %%
# !ls -l|wc -l
# Out:
# 22
